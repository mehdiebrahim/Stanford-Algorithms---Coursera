# %%
import pandas as pd
import sys
import os

os.chdir('/Users/mehdiebrahim/Desktop/Stanford Algorithms - Data')
data = pd.read_csv('numbers.txt',sep=' ',header=None)
data.columns = ['a']
L = list(data['a'])
n = len(L)
inv_count = 0

def Merge(L,R,mid):
    global inv_count
    result = [0]*(len(L)+len(R))
    #temporary list in which to merge L and R
    i=j=k=0
#     print(L,R)
    
#     below is the main loop for comparing two sorted arrays to merge into result
    while i < len(L) and j < len(R): 
        if L[i] < R[j]: 
            result[k] = L[i] 
          
            i+=1
        else: 
            result[k] = R[j]
            inv_count+=mid-(i)
            j+=1
        k+=1
        # If you reach the end of either array, then you can
        # add the remaining elements from the other array to
        # the result and break the loop
        # this is necessary i.e if L=[1,2,4,9] R=[3,4,5,6] gives res 
        # [1,2,3,4,4,5,6,6] without the below step. 
        # In this case,i=3,j=4,k=7 so final element of L which is 9 
        # needs to be added. This step below would be necessary when
        # an element in L is bigger than all of elems in R
        # so the above loop breaks before 9 is copied in
    while i<len(L):
        result[k]=L[i]
        i+=1
        k+=1
        
    while j<len(R):
        result[k]=R[j]
        j+=1
        k+=1

    return result
    

def MergeSort(array):
      
    if len(array)==1:
        return array   #this way when the L or R inputted into Merge func has len=1 (after enough divides i.e array[:mid] and array[mid:], 
                       #MergeSort outputs the array which can be then sorted and merged by the Merge func. 
                       #Otherwise, MergeSort outputs None when the L or R has 
                       #which cannot be sorted and merged 
    mid = len(array)//2 
    L = array[:mid]
    R = array[mid:]
    

      
    return Merge(MergeSort(L),MergeSort(R),mid)
   

MergeSort(L)
print(inv_count,'invvvv')
# Out:
# 2407905288 invvvv

# %%
#mergesort and explanation of the nitty gritty

def Merge(L,R):

    result = [0]*(len(L)+len(R))
    #temporary list in which to merge L and R
    i=j=k=0
    
#     below is the main loop for comparing two sorted arrays to merge into result
    while i < len(L) and j < len(R): 
        if L[i] < R[j]: 
            result[k] = L[i] 
            i+=1
        else: 
            result[k] = R[j] 
            j+=1
        k+=1
#     print(L,R,'LR')

    
        # If you reach the end of either array, then you can
        # add the remaining elements from the other array to
        # the result and break the loop
        # this is necessary i.e if L=[1,2,4,9] R=[3,4,5,6] gives res 
        # [1,2,3,4,4,5,6,6] without the below step. 
        # In this case,i=3,j=4,k=7 so final element of L which is 9 
        # needs to be added. This step below would be necessary when
        # an element in L is bigger than all of elems in R
        # so the above loop breaks before 9 is copied in
    while i<len(L):
        result[k]=L[i]
        i+=1
        k+=1
        
    while j<len(R):
        result[k]=R[j]
        j+=1
        k+=1
    print(i,j)
    print(result)
    return result
    

def MergeSort(array):
      
    if len(array)==1:
        return array   #this way when the L or R inputted into Merge func has len=1 (after enough divides i.e array[:mid] and array[mid:], 
                       #MergeSort outputs the array which can be then sorted and merged by the Merge func. 
                       #Otherwise, MergeSort outputs None when the L or R has 
                       #which cannot be sorted and merged 
    mid = len(array)//2
    L = array[:mid]
    R = array[mid:]
    print(L,R)
      
    return Merge(MergeSort(L),MergeSort(R))
   

MergeSort(arr)
# inv_count

# %%
# example of problem we have if the code below:
#     while i<len(L):
#         result[k]=L[i]
#         i+=1
#         k+=1
        
#     while j<len(R):
#         result[k]=R[j]
#         j+=1
#         k+=1
# isn't in place

L=[1,3,9]
R = [1,2,4,6]
array = [1,3,9,1,2,4,6]
i=j=k=0
while i < len(L) and j <len(R): 
    if L[i] < R[j]: 
        array[k] = L[i] 
        i+=1
    else: 
        array[k] = R[j] 
        j+=1
    k+=1
    print(array)
print(i)
print(j)
# Out:
# [1, 3, 9, 1, 2, 4, 6]
# [1, 1, 9, 1, 2, 4, 6]
# [1, 1, 2, 1, 2, 4, 6]
# [1, 1, 2, 3, 2, 4, 6]
# [1, 1, 2, 3, 4, 4, 6]
# [1, 1, 2, 3, 4, 6, 6]
# 2
# 4

# %%
import pandas as pd
import sys
import os
# mergesort for all in one function rather than a separate func for merge


os.chdir('/Users/mehdiebrahim/Desktop')
data = pd.read_csv('numbers.txt',sep=' ',header=None)
data.columns = ['a']
L = list(data['a'])
n = len(L)
arr = [3,4,1,5,2,1,8,6]
C= [0]*len(arr)
C



def MergeSort(array):
    
    if len(array)>1:

        mid = len(array)//2 + len(array)%2
        L = array[:mid]
        R = array[mid:]
      
        MergeSort(L)
        MergeSort(R)
        i=j=k=0
        
        while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                array[k] = L[i] 
                i+=1
            else: 
                array[k] = R[j] 
                j+=1
            k+=1
        print(L,R,'LR')
#         print(i,j)
       
        while i<len(L):
            array[k]=L[i]
            i+=1
            k+=1
        
        while j<len(R):
            array[k]=R[j]
            j+=1
            k+=1
